# %%
ls data
# Out:
# 10-54-23.jpg  11-04-02.jpg  11-13-43.jpg  11-23-21.jpg  11-33-00.jpg
# 10-57-36.jpg  11-07-16.jpg  11-16-55.jpg  11-26-34.jpg  11-36-13.jpg
# 11-00-49.jpg  11-10-30.jpg  11-20-08.jpg  11-29-47.jpg  11-39-27.jpg

# %%
# Import Libraries 
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import matplotlib.image


import cv2
import os
import PIL
from PIL import Image 
from glob import glob
import numpy as np
# %matplotlib inline

# %%
dir = os.path.join("data", "*.jpg")
file_list = [file for file in glob(dir)]
print(file_list)
# Out:
# ['data/11-26-34.jpg', 'data/11-36-13.jpg', 'data/11-10-30.jpg', 'data/11-33-00.jpg', 'data/10-57-36.jpg', 'data/10-54-23.jpg', 'data/11-39-27.jpg', 'data/11-07-16.jpg', 'data/11-13-43.jpg', 'data/11-29-47.jpg', 'data/11-04-02.jpg', 'data/11-23-21.jpg', 'data/11-16-55.jpg', 'data/11-20-08.jpg', 'data/11-00-49.jpg']

# %%
file_list[0]
# Out:
# 'data/11-26-34.jpg'

# %%
dir = os.path.join("output-images", "filled*.jpg")
filled_list = [file for file in glob(dir)]
print(filled_list)

# %%
filled_list[0]
# Out:
# 'output-images/colorspaces-11-29-47.jpg'

# %%
img_array = []
plot_array = []
for filename in file_list:
    img = plt.imread(filename)
    img_array.append(img)
    
    imgplot = plt.imshow(img)
    plot_array.append([imgplot])

# %%
output_array = []
for filename in filled_list:
    output_img = plt.imread(filename)
    output_array.append(output_img)

# %%
fig, ax = plt.subplots()
im = ax.imshow(output_array[0])


ax.axis('off')
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, dpi=300)
ax1.axis('off')
ax2.axis('off')

ax1.imshow(img_array[0])
ax1.set_title('Original Image')
ax2.imshow(output_array[0])
ax2.set_title('Segmented')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
fig, (ax1, ax2) = plt.subplots(1, 2,dpi=300)
ax1.axis('off')
ax2.axis('off')
ax1.set_title('Original Image')
ax2.set_title('Segmented')

original = [ax1.imshow(img_array[0])]
segmented = [ax2.imshow(output_array[0])]

#initialization of animation, plot array of zeros 
def init():
    return original
    return segmented

def animate(i):
    original = [ax1.imshow(img_array[i])]
    segmented = [ax2.imshow(output_array[i])]
    
    return original
    return segmented


frame_max=len(img_array)
anim = animation.FuncAnimation(fig, animate, init_func=init, repeat = True,
                               frames=range(0,frame_max), interval=1000, blit=True, repeat_delay=1000)

anim.save('test.gif')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/anaconda3/envs/env-plantcv/lib/python3.7/site-packages/matplotlib/animation.py in saving(self, fig, outfile, dpi, *args, **kwargs)
#     235         try:
# --> 236             yield self
#     237         finally:
#
# ~/anaconda3/envs/env-plantcv/lib/python3.7/site-packages/matplotlib/animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1176                         frame_number += 1
# -> 1177                 writer.grab_frame(**savefig_kwargs)
#    1178
#
# ~/anaconda3/envs/env-plantcv/lib/python3.7/site-packages/matplotlib/animation.py in grab_frame(self, **savefig_kwargs)
#     356         self.fig.savefig(self._proc.stdin, format=self.frame_format,
# --> 357                          dpi=self.dpi, **savefig_kwargs)
#     358
#
# ~/anaconda3/envs/env-plantcv/lib/python3.7/site-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    3014
# -> 3015         self.canvas.print_figure(fname, **kwargs)
#    3016
#
# ~/anaconda3/envs/env-plantcv/lib/python3.7/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2260                         bbox_inches_restore=_bbox_inches_restore,
# -> 2261                         **kwargs)
#    2262             finally:
#
# ~/anaconda3/envs/env-plantcv/lib/python3.7/site-packages/matplotlib/backend_bases.py in wrapper(*args, **kwargs)
#    1668
# -> 1669         return func(*args, **kwargs)
#    1670
#
# ~/anaconda3/envs/env-plantcv/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in print_raw(self, filename_or_obj, *args)
#     451     def print_raw(self, filename_or_obj, *args):
# --> 452         FigureCanvasAgg.draw(self)
#     453         renderer = self.get_renderer()
#
# ~/anaconda3/envs/env-plantcv/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     405               else nullcontext()):
# --> 406             self.figure.draw(self.renderer)
#     407             # A GUI class may be need to update a window using this draw, so
#
# ~/anaconda3/envs/env-plantcv/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      73     def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 74         result = draw(artist, renderer, *args, **kwargs)
#      75         if renderer._rasterizing:
#
# ~/anaconda3/envs/env-plantcv/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      50
# ---> 51             return draw(artist, renderer, *args, **kwargs)
#      52         finally:
#
# ~/anaconda3/envs/env-plantcv/lib/python3.7/site-packages/matplotlib/figure.py in draw(self, renderer)
#    2790             mimage._draw_list_compositing_images(
# -> 2791                 renderer, self, artists, self.suppressComposite)
#    2792
#
# ~/anaconda3/envs/env-plantcv/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#
# ~/anaconda3/envs/env-plantcv/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      50
# ---> 51             return draw(artist, renderer, *args, **kwargs)
#      52         finally:
#
# ~/anaconda3/envs/env-plantcv/lib/python3.7/site-packages/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     430                 **kwargs)
# --> 431         return func(*inner_args, **inner_kwargs)
#     432
#
# ~/anaconda3/envs/env-plantcv/lib/python3.7/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2920
# -> 2921         mimage._draw_list_compositing_images(renderer, self, artists)
#    2922
#
# ~/anaconda3/envs/env-plantcv/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#
# ~/anaconda3/envs/env-plantcv/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      50
# ---> 51             return draw(artist, renderer, *args, **kwargs)
#      52         finally:
#
# ~/anaconda3/envs/env-plantcv/lib/python3.7/site-packages/matplotlib/image.py in draw(self, renderer, *args, **kwargs)
#     640             im, l, b, trans = self.make_image(
# --> 641                 renderer, renderer.get_image_magnification())
#     642             if im is not None:
#
# ~/anaconda3/envs/env-plantcv/lib/python3.7/site-packages/matplotlib/image.py in make_image(self, renderer, magnification, unsampled)
#     926         return self._make_image(self._A, bbox, transformed_bbox, clip,
# --> 927                                 magnification, unsampled=unsampled)
#     928
#
# ~/anaconda3/envs/env-plantcv/lib/python3.7/site-packages/matplotlib/image.py in _make_image(self, A, in_bbox, out_bbox, clip_bbox, magnification, unsampled, round_to_pixel_border)
#     551                 output = _resample(  # resample rgb channels
# --> 552                     self, _rgb_to_rgba(A[..., :3]), out_shape, t, alpha=alpha)
#     553                 output[..., 3] = output_alpha  # recombine rgb and alpha
#
# ~/anaconda3/envs/env-plantcv/lib/python3.7/site-packages/matplotlib/image.py in _resample(image_obj, data, out_shape, transform, resample, alpha)
#     197                     image_obj.get_filternorm(),
# --> 198                     image_obj.get_filterrad())
#     199     return out
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# CalledProcessError                        Traceback (most recent call last)
# /tmp/ipykernel_51269/2885717363.py in <module>
#      25                                frames=range(0,frame_max), interval=1000, blit=True, repeat_delay=1000)
#      26
# ---> 27 anim.save('test.gif')
#      28 plt.show()
#
# ~/anaconda3/envs/env-plantcv/lib/python3.7/site-packages/matplotlib/animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1175                         progress_callback(frame_number, total_frames)
#    1176                         frame_number += 1
# -> 1177                 writer.grab_frame(**savefig_kwargs)
#    1178
#    1179     def _step(self, *args):
#
# ~/anaconda3/envs/env-plantcv/lib/python3.7/contextlib.py in __exit__(self, type, value, traceback)
#     128                 value = type()
#     129             try:
# --> 130                 self.gen.throw(type, value, traceback)
#     131             except StopIteration as exc:
#     132                 # Suppress StopIteration *unless* it's the same exception that
#
# ~/anaconda3/envs/env-plantcv/lib/python3.7/site-packages/matplotlib/animation.py in saving(self, fig, outfile, dpi, *args, **kwargs)
#     236             yield self
#     237         finally:
# --> 238             self.finish()
#     239
#     240
#
# ~/anaconda3/envs/env-plantcv/lib/python3.7/site-packages/matplotlib/animation.py in finish(self)
#     345             overridden_cleanup()
#     346         else:
# --> 347             self._cleanup()  # Inline _cleanup() once cleanup() is removed.
#     348
#     349     def grab_frame(self, **savefig_kwargs):
#
# ~/anaconda3/envs/env-plantcv/lib/python3.7/site-packages/matplotlib/animation.py in _cleanup(self)
#     377         if self._proc.returncode:
#     378             raise subprocess.CalledProcessError(
# --> 379                 self._proc.returncode, self._proc.args, out, err)
#     380
#     381     @_api.deprecated("3.4")
#
# CalledProcessError: Command '['ffmpeg', '-f', 'rawvideo', '-vcodec', 'rawvideo', '-s', '1800x1200', '-pix_fmt', 'rgba', '-r', '1.0', '-loglevel', 'error', '-i', 'pipe:', '-filter_complex', 'split [a][b];[a] palettegen [p];[b][p] paletteuse', '-y', 'test.gif']' returned non-zero exit status 255.

# %%
fig = plt.figure()
ax = plt.gca()


## create an instance of animation
anim = animation.ArtistAnimation(fig, img_array, interval=1000, blit=True, repeat_delay=1000)

## NB: The 'save' method here belongs to the object you created above
anim.save("anim.gif")

## Showtime!
plt.show()

# %%
import cv2
import numpy as np
import os

image_folder = 'data'
video_file = 'vid.avi'
image_size = (1600, 1200)
fps = 1

images = [img for img in os.listdir(image_folder) if img.endswith(".jpg")]
images.sort()
file_list.sort()
out = cv2.VideoWriter(video_file, cv2.VideoWriter_fourcc(*'MJPG'), fps, image_size)

img_array = []
for filename in file_list:
    img = cv2.imread(filename)
    img_array.append(img)
    out.write(img)

out.release()

# %%
img_list = []
cv2_img_list= []
im_list = []
for file in file_list:
    img = Image.open(file)
    img_list.append(img)
    cv2_img = cv2.imread(file)
    cv2_img_list.append(cv2_img)
    imgplot = plt.imshow(img,animated=True)
    im_list.append([imgplot])
print(im_list)

# %%
im_list[0]

# %%
fig= plt.figure(dpi=200)

ani = animation.ArtistAnimation(fig, im_list)
writer = animation.FFMpegWriter(fps=2)
ani.save('file.gif',writer=writer)

plt.show()

# %%
from matplotlib import animation  
import matplotlib.image as mgimg
import numpy as np

#set up the figure
fig = plt.figure()
ax = plt.gca()

#initialization of animation, plot array of zeros 
def init():
    imobj.set_data(np.zeros((100, 100)))

    return  imobj,

def animate(i):
    ## Read in picture
    fname = img_array[i] 

    ## here I use [-1::-1], to invert the array
    # IOtherwise it plots up-side down
    img = mgimg.imread(fname)[-1::-1]
    imobj.set_data(img)

    return  imobj,


## create an AxesImage object
imobj = ax.imshow( np.zeros((100, 100)), origin='lower', alpha=1.0, zorder=1, aspect=1 )


anim = animation.FuncAnimation(fig, animate, init_func=init, repeat = True,
                               frames=range(1,4), interval=200, blit=True, repeat_delay=1000)

anim.save()
plt.show()

# %%
outfile = 'output-images/' + 'base-anim.gif'
print(outfile)
img_list[0].save(outfile, save_all=True, append_images=img_list[1:], duration=2000, loop=1)

# %%
cv2.imshow('image',cv2_img_list)

# %%
img_array = []
for file in file_list:
    img = Image.open(file)
    img_array.append(img)
    print(file)
img_array

# %%
# Create the frames

# Save into a GIF file that loops forever
img_array[0].save('test.gif', format='GIF',
               append_images=img_array[1:],
               save_all=True,
               duration=180, loop=0)

# %%
# %%HTML
# <video controls>
#   <source src="01.avi">
# </video>

# %%
from IPython.display import Video

#Video(‘https://archive.org/download/Sita_Sings_the_Blues/Sita_Sings_the_Blues_small.mp4’)
#Video(‘path/to/video.mp4’)
Video('01.mp4', embed=True)
#Video(b’raw-videodata’, embed=True)
