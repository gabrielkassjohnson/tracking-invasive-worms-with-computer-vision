# %%
ls data
# Out:
# 08-12-17.jpg  08-17-29.jpg  08-22-41.jpg  08-27-52.jpg

# %%
# Import Libraries 
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import matplotlib.image


import cv2
import os
import PIL
from PIL import Image 
from glob import glob
import numpy as np
# %matplotlib notebook

# %%
dir = os.path.join("data", "*.jpg")
file_list = [file for file in glob(dir)]
print(file_list)
# Out:
# ['data/08-12-17.jpg', 'data/08-22-41.jpg', 'data/08-17-29.jpg', 'data/08-27-52.jpg']

# %%
file_list[0]
# Out:
# 'data/08-12-17.jpg'

# %%
# Create the frames
img_array = []
for file in file_list:
    img = Image.open(file)
    img_array.append(img)
    print(file)

# Save into a GIF file that loops forever
img_array[0].save('test.gif', format='GIF',
               append_images=img_array[1:],
               save_all=True,
               duration=180, loop=0)
# Out:
# 3/envs/env-plantcv/lib/python3.7/site-packages/matplotlib/animation.py", line 1776, in _draw_frame
#     self._drawn_artists = self._func(framedata, *self._args)
#   File "/tmp/ipykernel_45358/3323461182.py", line 17, in animate
#     fname = img_array[i]
# IndexError: list index out of range
# data/08-12-17.jpg
# data/08-17-29.jpg
# data/08-22-41.jpg
# data/08-27-52.jpg

# %%
img_array = []
for filename in file_list:
    img = matplotlib.image.imread(filename)
    imgplot = plt.imshow(img)

    img_array.append([imgplot])
# Out:
# <img src="data:image/png;base64,..." width="697.5833333333334">

# %%
img_array
# Out:
# [[<matplotlib.image.AxesImage at 0x7fcfc3a25950>],
#  [<matplotlib.image.AxesImage at 0x7fcfc38b8210>],
#  [<matplotlib.image.AxesImage at 0x7fcfe0b02e90>],
#  [<matplotlib.image.AxesImage at 0x7fcfb93aaa50>]]

# %%
fig = plt.figure()
ax = plt.gca()


## create an instance of animation
anim = animation.ArtistAnimation(fig, img_array, interval=1000, blit=True, repeat_delay=1000)

## NB: The 'save' method here belongs to the object you created above
anim.save("anim.gif")

## Showtime!
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="697.5833333333334">

# %%
import cv2
import numpy as np
import os

image_folder = 'data'
video_file = 'vid.avi'
image_size = (1600, 1200)
fps = 1

images = [img for img in os.listdir(image_folder) if img.endswith(".jpg")]
images.sort()
file_list.sort()
out = cv2.VideoWriter(video_file, cv2.VideoWriter_fourcc(*'MJPG'), fps, image_size)

img_array = []
for filename in file_list:
    img = cv2.imread(filename)
    img_array.append(img)
    out.write(img)

out.release()

# %%
img_list = []
cv2_img_list= []
im_list = []
for file in file_list:
    img = Image.open(file)
    img_list.append(img)
    cv2_img = cv2.imread(file)
    cv2_img_list.append(cv2_img)
    imgplot = plt.imshow(img,animated=True)
    im_list.append([imgplot])
print(im_list)
# Out:
# [[<matplotlib.image.AxesImage object at 0x7fcfb9366e10>], [<matplotlib.image.AxesImage object at 0x7fcfb9299190>], [<matplotlib.image.AxesImage object at 0x7fcfb9366fd0>], [<matplotlib.image.AxesImage object at 0x7fcfb9299910>]]

# %%
im_list[0]

# %%
fig= plt.figure(dpi=200)

ani = animation.ArtistAnimation(fig, im_list)
writer = animation.FFMpegWriter(fps=2)
ani.save('file.gif',writer=writer)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1279.6666666666667">

# %%
from matplotlib import animation  
import matplotlib.image as mgimg
import numpy as np

#set up the figure
fig = plt.figure()
ax = plt.gca()

#initialization of animation, plot array of zeros 
def init():
    imobj.set_data(np.zeros((100, 100)))

    return  imobj,

def animate(i):
    ## Read in picture
    fname = img_array[i] 

    ## here I use [-1::-1], to invert the array
    # IOtherwise it plots up-side down
    img = mgimg.imread(fname)[-1::-1]
    imobj.set_data(img)

    return  imobj,


## create an AxesImage object
imobj = ax.imshow( np.zeros((100, 100)), origin='lower', alpha=1.0, zorder=1, aspect=1 )


anim = animation.FuncAnimation(fig, animate, init_func=init, repeat = True,
                               frames=range(1,4), interval=200, blit=True, repeat_delay=1000)

anim.save()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="697.5833333333334">

# %%
outfile = 'output-images/' + 'base-anim.gif'
print(outfile)
img_list[0].save(outfile, save_all=True, append_images=img_list[1:], duration=2000, loop=1)
# Out:
# output-images/base-anim.gif

# %%
cv2.imshow('image',cv2_img_list)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_45358/3283220620.py in <module>
# ----> 1 cv2.imshow('image',cv2_img_list)
#
# TypeError: mat is not a numpy array, neither a scalar

# %%
# %%HTML
# <video controls>
#   <source src="01.avi">
# </video>

# %%
from IPython.display import Video

#Video(‘https://archive.org/download/Sita_Sings_the_Blues/Sita_Sings_the_Blues_small.mp4’)
#Video(‘path/to/video.mp4’)
Video('01.mp4', embed=True)
#Video(b’raw-videodata’, embed=True)
